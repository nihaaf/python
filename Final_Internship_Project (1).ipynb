# %%
import pandas as pd
df=pd.read_csv("Data.csv (1).csv")
df.head(10)
# Out:
#    Order_ID Customer_ID Customer_Name     City   Restaurant Popular_Food_Item  \
# 0      1001        C001    Customer_1    Erode          KFC    Chicken Bucket
# 1      1002        C002    Customer_2    Salem          KFC     Zinger Burger
# 2      1003        C003    Customer_3  Madurai       Subway        Paneer Sub
# 3      1004        C004    Customer_4    Salem      Dominos  Veg Extravaganza
# 4      1005        C005    Customer_5    Salem       Subway       Chicken Sub
# 5      1006        C006    Customer_6  Chennai       Subway        Paneer Sub
# 6      1007        C007    Customer_7   Trichy          KFC         Hot Wings
# 7      1008        C008    Customer_8   Trichy  Burger King    Whopper Burger
# 8      1009        C009    Customer_9    Erode    Pizza Hut   Pepperoni Pizza
# 9      1010        C010   Customer_10   Trichy  Burger King   Chicken Whopper
#
#    Discount_Percentage  Order_Date  Order_Value  Delivery_Time_Minutes  \
# ...

# %%
df.head()
# Out:
#    Order_ID Customer_ID Customer_Name     City Restaurant Popular_Food_Item  \
# 0      1001        C001    Customer_1    Erode        KFC    Chicken Bucket
# 1      1002        C002    Customer_2    Salem        KFC     Zinger Burger
# 2      1003        C003    Customer_3  Madurai     Subway        Paneer Sub
# 3      1004        C004    Customer_4    Salem    Dominos  Veg Extravaganza
# 4      1005        C005    Customer_5    Salem     Subway       Chicken Sub
#
#    Discount_Percentage  Order_Date  Order_Value  Delivery_Time_Minutes  \
# 0                   10  2026-03-02         1214                     43
# 1                    0  2026-07-19         1086                     53
# 2                   25  2026-04-28         1410                     21
# 3                   20  2026-01-05          980                     58
# 4                    5  2026-08-13         1215                     50
#
#    Rating Payment_Method
# 0     4.2           Card
# 1     4.6            UPI
# ...

# %%
import pandas as pd
df.tail()
# Out:
#      Order_ID Customer_ID Customer_Name     City Restaurant Popular_Food_Item  \
# 995      1996        C496  Customer_496  Madurai        KFC         Hot Wings
# 996      1997        C497  Customer_497  Madurai    Dominos  Margherita Pizza
# 997      1998        C498  Customer_498    Salem  Pizza Hut      Cheese Pizza
# 998      1999        C499  Customer_499  Chennai  McDonalds    Big Mac Burger
# 999      2000        C500  Customer_500    Salem     Subway       Chicken Sub
#
#      Discount_Percentage  Order_Date  Order_Value  Delivery_Time_Minutes  \
# 995                   20  2026-07-30         1445                     22
# 996                    0  2026-10-10          205                     59
# 997                   10  2026-10-27         1022                     18
# 998                    0  2026-03-24         1114                     18
# 999                    0  2026-09-28          544                     60
#
#      Rating Payment_Method
# 995     3.9           Card
# ...

# %%
import pandas as pd
df.tail(20)
# Out:
#      Order_ID Customer_ID Customer_Name        City   Restaurant  \
# 980      1981        C481  Customer_481     Chennai          KFC
# 981      1982        C482  Customer_482       Erode    McDonalds
# 982      1983        C483  Customer_483      Trichy    Pizza Hut
# 983      1984        C484  Customer_484       Erode          KFC
# 984      1985        C485  Customer_485     Chennai       Subway
# 985      1986        C486  Customer_486      Trichy  Burger King
# 986      1987        C487  Customer_487  Coimbatore    Pizza Hut
# 987      1988        C488  Customer_488      Trichy          KFC
# 988      1989        C489  Customer_489  Coimbatore    McDonalds
# 989      1990        C490  Customer_490      Trichy      Dominos
# 990      1991        C491  Customer_491     Madurai  Burger King
# 991      1992        C492  Customer_492       Salem    Pizza Hut
# 992      1993        C493  Customer_493     Chennai          KFC
# ...

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'City', 'Restaurant',
#        'Popular_Food_Item', 'Discount_Percentage', 'Order_Date', 'Order_Value',
#        'Delivery_Time_Minutes', 'Rating', 'Payment_Method'],
#       dtype='object')

# %%
import pandas as pd
df.describe()
# Out:
#           Order_ID  Discount_Percentage  Order_Value  Delivery_Time_Minutes  \
# count  1000.000000          1000.000000  1000.000000            1000.000000
# mean   1500.500000            12.490000   838.628000              37.344000
# std     288.819436             8.495415   364.263695              12.892086
# min    1001.000000             0.000000   201.000000              15.000000
# 25%    1250.750000             5.000000   533.500000              26.000000
# 50%    1500.500000            10.000000   834.500000              37.000000
# 75%    1750.250000            20.000000  1129.250000              49.000000
# max    2000.000000            25.000000  1500.000000              60.000000
#
#             Rating
# count  1000.000000
# mean      4.256300
# std       0.440448
# min       3.500000
# 25%       3.900000
# 50%       4.300000
# 75%       4.600000
# max       5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               1000 non-null   int64
#  1   Customer_ID            1000 non-null   object
#  2   Customer_Name          1000 non-null   object
#  3   City                   1000 non-null   object
#  4   Restaurant             1000 non-null   object
#  5   Popular_Food_Item      1000 non-null   object
#  6   Discount_Percentage    1000 non-null   int64
#  7   Order_Date             1000 non-null   object
#  8   Order_Value            1000 non-null   int64
#  9   Delivery_Time_Minutes  1000 non-null   int64
#  10  Rating                 1000 non-null   float64
#  11  Payment_Method         1000 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 93.9+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID                 0
# Customer_ID              0
# Customer_Name            0
# City                     0
# Restaurant               0
# Popular_Food_Item        0
# Discount_Percentage      0
# Order_Date               0
# Order_Value              0
# Delivery_Time_Minutes    0
# Rating                   0
# Payment_Method           0
# dtype: int64

# %% [markdown]
# payment method

# %%
df.groupby("Restaurant")
df.groupby("Payment_Method")['Order_Value'].sum()
# Out:
# Payment_Method
# Card    299615
# Cash    276177
# UPI     262836
# Name: Order_Value, dtype: int64

# %% [markdown]
# delivery minutes

# %%
City_delivery = df.groupby("City")["Delivery_Time_Minutes"].sum()
print(City_delivery)
# Out:
# City
# Chennai       6966
# Coimbatore    5371
# Erode         7285
# Madurai       5925
# Salem         6105
# Trichy        5692
# Name: Delivery_Time_Minutes, dtype: int64

# %% [markdown]
# average

# %%
df["Average"]=df['Delivery_Time_Minutes'].mean()
df[['City','Average']].head(7)
# Out:
#       City  Average
# 0    Erode   37.344
# 1    Salem   37.344
# 2  Madurai   37.344
# 3    Salem   37.344
# 4    Salem   37.344
# 5  Chennai   37.344
# 6   Trichy   37.344

# %% [markdown]
# rating

# %%
df.groupby("City")
df[['City','Rating']].head(20)
# Out:
#           City  Rating
# 0        Erode     4.2
# 1        Salem     4.6
# 2      Madurai     4.9
# 3        Salem     3.8
# 4        Salem     3.8
# 5      Chennai     4.9
# 6       Trichy     4.3
# 7       Trichy     4.8
# 8        Erode     4.5
# 9       Trichy     4.5
# 10       Erode     3.6
# 11       Erode     4.3
# 12       Erode     4.9
# 13     Madurai     4.1
# 14     Chennai     4.2
# 15       Erode     4.1
# 16       Erode     3.5
# 17     Chennai     4.7
# 18      Trichy     4.6
# 19  Coimbatore     3.6

# %% [markdown]
# total revenue

# %%
total_revenue=df.groupby("City")["Order_Value"].sum()
print(total_revenue)
# Out:
# City
# Chennai       155648
# Coimbatore    119006
# Erode         160140
# Madurai       140670
# Salem         135224
# Trichy        127940
# Name: Order_Value, dtype: int64

# %% [markdown]
# most popular food

# %%
df.groupby("City")
df[['City','Restaurant','Popular_Food_Item']].head(20)
# Out:
#           City   Restaurant Popular_Food_Item
# 0        Erode          KFC    Chicken Bucket
# 1        Salem          KFC     Zinger Burger
# 2      Madurai       Subway        Paneer Sub
# 3        Salem      Dominos  Veg Extravaganza
# 4        Salem       Subway       Chicken Sub
# 5      Chennai       Subway        Paneer Sub
# 6       Trichy          KFC         Hot Wings
# 7       Trichy  Burger King    Whopper Burger
# 8        Erode    Pizza Hut   Pepperoni Pizza
# 9       Trichy  Burger King   Chicken Whopper
# 10       Erode          KFC     Zinger Burger
# 11       Erode  Burger King   Chicken Whopper
# 12       Erode          KFC         Hot Wings
# 13     Madurai    McDonalds  McChicken Burger
# 14     Chennai  Burger King   Chicken Whopper
# 15       Erode  Burger King    Whopper Burger
# 16       Erode  Burger King   Chicken Whopper
# 17     Chennai       Subway       Chicken Sub
# 18      Trichy      Dominos  Margherita Pizza
# ...

# %%
df['Delivery_Time_Minutes'].min()
# Out:
# 15

# %%
df['Rating'].max()
# Out:
# 5.0

# %%
df['Rating'].min()
# Out:
# 3.5

# %%
df['Total_amount'] = df['Order_Value']
df[['Customer_ID', 'City', 'Popular_Food_Item', 'Order_Value']].head(5)
# Out:
#   Customer_ID     City Popular_Food_Item  Order_Value
# 0        C001    Erode    Chicken Bucket         1214
# 1        C002    Salem     Zinger Burger         1086
# 2        C003  Madurai        Paneer Sub         1410
# 3        C004    Salem  Veg Extravaganza          980
# 4        C005    Salem       Chicken Sub         1215

# %% [markdown]
# payment visualization

# %%
import matplotlib.pyplot as plt
df=pd.read_csv("Data.csv (1).csv")
payment_counts=df['Payment_Method'].value_counts()
plt.bar(payment_counts.index, payment_counts.values)
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Payment Method Distribution')
plt.show()

# %% [markdown]
# popular food visualization

# %%
from numpy import histogram
import matplotlib.pyplot as plt
food_counts=df['Popular_Food_Item'].value_counts()
food_counts.plot(kind='bar',color='pink')
plt.title("Most Popular Food Item")
plt.xlabel("Food Item")
plt.ylabel("Number of orders")
plt.xticks(rotation=60)
plt.show()

# %%
rating visualization

# %%
import matplotlib.pyplot as plt
rating_counts=df["Rating"].value_counts()
rating_counts.plot(kind='pie',color='green')
plt.title("Rating distibution")
plt.xlabel("Rating")
plt.ylabel("Number of orders")
plt.show()
